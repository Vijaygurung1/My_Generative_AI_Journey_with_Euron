# %% [markdown]
# # Vector_Database No.5 : [ Weaviate_DB ]

# %% [markdown]
# Google it -> "Weaviate_DB" URL : [ https://weaviate.io/ ]

# %% [markdown]
# - click on Try now & signup.
# - This is the home page URL : [ https://console.weaviate.cloud/ ]

# %% [markdown]
# # Note : Pricing Different Different Vector databse :
#
# - Here, we can observed that, they are only providing the "Embeddings", they have also provided the "Agents", left side we can it.
# - sometime similar kind of "Agents", we will be see in other vendors also like in "Chroma_DB", "Pine_Cone", if one have done this
# - other vendor also sure they will soon do.
# - Most of the all these Vector Database, we have observed that, it is providing us a "Embeddings".
# - Again, "Embeddings" will be on my control, If I would like to give X,y & G model, I can try to use X,Y & G model.
# - Everyone is providing a "Cosine", everyone is giving me a "Gradient". Everyone is providing a dot(.) product.
# - Even incase of a distance matching all are providing us all these facilities.
# - Again there is no differnece at all.
# - The only difference, we are able to find out is technically a Pricing part. whenever we are try to decide, we have to go with the
# - "Weaviate_DB" or "Pincone_DB",or "chroma_DB" or "Qdrant_DB", generally we think about the pricing in a very very 1st place & with that
# - pricing,
# - 1.what instances they are porviding me.
# - 2.what kind of uptime
# - 3.What kind of Latency my application will be able to face.
# - we just try to consider that part, facilities and features wise, & under the hood, we will be able to find out that, everyone is
# - doing the same thing.
# - It is something like we are picking any of the vendor like : GCP, AWs or Azure.
# - All the services are avaiable AWs, similart in GCP or Azure etc...Depend on there marketing, depends on there Custome acquisition.
# - Aws, we all know, has bigger market majority of the cloud customers able to secure.
# - Not only Aws, Azure is also able to secure good market.

# %% [markdown]
# # Public Question :
# - whats there Performace in the market?
# - Performance wise, it depends upon the instances, when we go with the paid plan, they will provide you the instances.
#
# # "PineCode Database" :
#
# - When we was exploring "pinecode Database", at that we have observed that, they are not using there own hosting, they were providing
# - Aws, Azure or GCP hosting.
# - If we go and check, so basically they have created the Services under those services they have created basically services means
# - converting something into the "Embedding", storing it doing a search, doing a Cosine, similary search or maybe "Euclidean distance"
# - or maybe a Dot(.) product search, there were not hosting directly, they were basically using instances of AWS, Azure and GCP.
# - because end of the day, any servies on a cloud, I need a machine, "Cloud" is just a machine the way we are running someting in my
# - laptop, similar manner that laptop is global & that we used to call as cloud.
# - So, the cost depend on the instances that we were going to use, plus the instances that we are going to use plus there pricing model,
# - some of them will going to charges depend upon there instances.
# - For Example : IF I have taken a like configuration, with XyZ with AWS. So there will be maybe fixed cost most of the time.
# - If we take an example of our plaform - ["Euron"], we are using a "Vector_DB", for our "Job Application" & to do a filteration, to do
# - a search, most of the time, we will be having basically a corporate tie up, in that way we try to negotiate, we say that we are not
# - going to pay you, "pay per use", we dont want to go with the that model. So, we would like to go ahead with the server means
# - for the next 3 or 4 years we are going to reserve, in that case my reserved will be the 70% to 80% less and even for them
# - cost will be 70% to 80% less even AWS, Azure & GCP is providing us a reserved model, for 3 years or more we can try to reserved
# -  the entire instances then our prices will be 70% -80% down.
# - If we go with the "pay per" use model, again they will going to charge us for every hit, for the network "IO" they are going to charge.
# - for the "Embeddings", they were goimg to charge for "Search Query", they were going to charge for everything. But again, everone has
# - different different kind of a pricing model by the way.
# - Keeping everything, in a mind we try to set the calculation that, this is my usages, and lets go ahead with "Pay per Use" model.
# - Let's go ahead with the maybe long term model, lets go ahead with the maybe some sort of a corporate client, or there are some,
# - 3rd party seller as well, sometime we go ahead with even that.

# %% [markdown]
# # Another senario :
#
# - Like just we are trying to create our startup and maybe we are trying to use a "OpenAI" API, & we have created our own startup.
#
# - For Example :
# - Let talk about the "Euron", here lest say we are providing "GPT5 or GPT4 model", access but "GPT5" model cant hosting it.
# - Its not the open sources model, by the way we cant host it.
# - Maybe 20B OSS or maybe 120B OSS, we can host it, that becasue that is an open sources format, "OpenAI" but if we talk about the a
# - GPT5 model, or GPT4 model, series, we cant host it, we can try to use there "API Key", we are trying to provide you.
# - So, basically, we have provided one more layer on top of it, a rapper layer so that we can go through our system.
# - But technically we are accessing the "OpenAI" itself.
# - Even this embaddings model that, we have used, so we are going through "Euri API", but technically what we are able to access.
# - the same one, if we would like to access same from "OpenAI", maybe they will charge after sometime.

# %% [markdown]
# # Next :
#
# - Now lets start, URL : [ https://console.weaviate.cloud/ ]
# - Now, we have to create the "Cluster" click on -> [ "Create Cluster" ] <- "Clusters" means instances.
# - so, here -> select the -> ["Sandbox"] <- a free one. others are charging. So, Sanbox means experimentation box.
# - 1.General Information :
# - I will provide the name -> ["vijaygurung"] <- leave all things as it  is.
# - If we scroll little bit, then there is a -> ["Cluster Quota"] <- there is a "Vector Dimension".
# - what was our vector Dimension. [ 256 | 768 | 1536 ] . So we all know, what option, we will going ("1536"), option picked.
# - Now lets click on "Create" then it will create my "Cluster". It will take sometime to install it.

# %% [markdown]
# # Note : Why we are learning Vector_DB?
#
# - what is the use cases,
# - we are going to use "Vector_DB" tons of use cases.
# - 1.Very 1st use cases is RAG base use cases. Tomorrow leacture we will discussed this, on our project.
# - 2.we can try to use immeditely in our company, wherever we have to do product search.
# - For Example :
# - Amazon search, Flipkart Search, Myntra search. Wherver we have to product search user can type anything, but still they will get the
# - proper result.But again alot of Tunning required in that case.
# - Let's say, I am doing a code search. Lets say I have code repository, where I have a millions line of codes, because every big company
# - there will be a million lines of code. we are looking for something where it should be able to do a search immediately.
# - Plus, it should be able to do a refinement. I can try to use a "RAG" kind of application with respect to a code search.
# - Deduping, Let suppose, If I have to removed the duplicates, not the exact word matching. But a semantic meaning matching duplication
# - If we have to remove. Again we can try to use a "Vector Database" for that one.
# -
# # Example :
# - Lets say I am trying to build a Modern recommendation system, we all aware about the recommendation system.
# - If we go Amzon, Flipkart or YouTube, it recommendates us alot of things, if we take example of "instagram" also. It recommendation
# - alot of things, so everywhere all the application, are using the recommendation system, bydefault.
# - Lets suppose, I would like to build my own best recommendation system, I can use the "Vector Database".
# - Let's suppose, I have to perform a clustering group. Grouping operation, so I have to seperate the the segregate the data.
# - Based on the cities or based on the countries or based on some other parameters.
# - Let's say, I have to do a some short of "Anomaly" detection.
# - May be "DDos" kind of attack kind of things, Maybe I am trying to build something for the Cyber Security, something from the Banking &
# - Finance Application, or anywhere maybe a drug discovery or drug anomaly detection, if we are trying to do so.
# - Even there we can use the "Vector database".
# - Its not just for 1 single application. when we talk about the [ "Vector DB" ].
#
# # Point No.1:
#
# - People say, we only use Vector_DB with the RAGapplication.?
# - But no its technically a data, which is trying to store something, in a numerical format & which is helping out interms of
# - better search, based on the semantic, my use cases would be infinite in that situation.

# %% [markdown]
# # Libaries :
# - 1.Weaviate

# %%
pip install weaviate-client==3.26.1
# Out:
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.5 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.5 MB 599.9 kB/s eta 0:00:05
#    ----- ---------------------------------- 0.5/3.5 MB 599.9 kB/s eta 0:00:05
#    ----- ---------------------------------- 0.5/3.5 MB 599.9 kB/s eta 0:00:05
#    ----- ---------------------------------- 0.5/3.5 MB 599.9 kB/s eta 0:00:05
#    ----- ---------------------------------- 0.5/3.5 MB 599.9 kB/s eta 0:00:05
#    ----- ---------------------------------- 0.5/3.5 MB 599.9 kB/s eta 0:00:05
#    -------- ------------------------------- 0.8/3.5 MB 316.6 kB/s eta 0:00:09
#    -------- ------------------------------- 0.8/3.5 MB 316.6 kB/s eta 0:00:09
#    ----------- ---------------------------- 1.0/3.5 MB 364.8 kB/s eta 0:00:07
# ...

# %% [markdown]
# # Import the libary

# %%
import weaviate

# %% [markdown]
# - Once our cluster is ready now, we will be able to see the 2 things,
# - 1.Our URL
# - 2.API key
# - This is going to create the client. This is the only things which is required.
# - Again, we will go with the insert operation, & then we will go ahead with the search operation.
# - So, now lets create the "API key"

# %%
export WEAVIATE_URL="3fw28y36qo4flgyflsxaw.c0.asia-southeast1.gcp.weaviate.cloud"
export WEAVIATE_API_KEY="<Your API Key>"

# %%
1import os
2import weaviate
3from weaviate.classes.init import Auth
4
5# Best practice: store your credentials in environment variables
6weaviate_url = os.environ["WEAVIATE_URL"]
7weaviate_api_key = os.environ["WEAVIATE_API_KEY"]
8
9# Connect to Weaviate Cloud
10client = weaviate.connect_to_weaviate_cloud(
11    cluster_url=weaviate_url,
12    auth_credentials=Auth.api_key(weaviate_api_key),
13)
14
15print(client.is_ready())
