# %% [markdown]
# # How to push code to GitHub
#
# -  Let's do it. Follow Steps : Inside Terminal | How to Push code to Github

# %% [markdown]
# - Now what we need to do it,
#
# - Come to our Terminal and Stop everything like just ["CTRL + C "] Hit eneter it will stop it. Type inside terminal ("Cls").
#
#
# # 1.[ "git init" ]
#
# - [ It means initialize it. So, whatever avaiable inside this location or inside my current Path ],
# - it will be initialize it, & we can see left side, my folder and venv section the color has changed, from white to blue.
#
# # 2.[ "git add" ]
#
# # Full code [" git add ."]
#
# - Now I will call the "Git add" and if we go and check in my Github Point No.2, "Git add" section -> ["git add README.md"]
#
# - I will not write the "README.md", I will write this way ["git add ."] or git add space dot(.) & hit enter.
#
# - dot(.) This means whatever file, avaiable inside my current Path, "APi2" folder add everything.
#
# # 3.[ " git Commit "]
#
# # Full code -> [" git commit -m "this is my first code " ]
#
# - This means we are doing some short of a commit, we are trying to send some code, but we would like to write some message with
# - that as well. So, that is the meanining of the Commitment.
#
# # For example :
#
# - We go and commit and promise something to our friends that does not mean, we will going to do it compltely.
# - Similar manner, so we are doing commit, lets keep it inside some buffer, does not mean I will push inside the cloude or Github.
# -  So, git commit (-m) this "hypen(-) m" -> means message, & I can write my message over here something like,
# - ["this is my 1st code"] <- something like this message & hit enter.
# - So, now it has successfully committed into a "Buffer memory", As of now code is not avaiable.
#
# - Its in a Buffer now, its Hung between my local system  to Github repository we can say.
# - Im repository code is not avaiable. I have just commited. which ever file we have created so far all of these commited.
#
# # Note :
#
# - If we get an error message that provide your Name and email id then, follow this steps, then try to commit once again.
#
# # Code No.1 :
# - [ git config --local user.name "Vijay Gurung" ] & hit enter
# # Code No.2 :
# - [ git config --local user.email "vijaygurung555@gmail.com" ] & hit enter
#
# - Then now try to commit, put this code -> [ " git commit -m "this is my first code " ] Now it will works.
#
#
# # 4.[ " git branch -M main "]
#
# - Now, once commit is done, Now we have to push the code, where we have to push the code. Inside the Git, there is Branching,
# - which will eventually, more and more clear once we will invlolved into it. By default there is the main branch, so in the
# - Main Brach, we try to push the code, So -> [" git branch -M main "] & hit enter.
#
#
# # 5.[" git remote add origin "]
#
# # Full code : [" git remote add origin https://github.com/Vijaygurung1/Api2.git "]
#
# - So, this is the location, where I have to place the code, What is the "URL", how someone, will be able to reach out to the
# - main branch?
# - So, " git remote add origin " & this is baiscally a place -> [" https://github.com/Vijaygurung1/Api2.git "], through which
# - someone can reach out to the main Branch.
#
# # Note :
#
# - For every repository, this will going to be different, My case we can see this created -> Api2.git.
#
# - just copy and paste inside terminal this full code, [ " git remote add origin https://github.com/Vijaygurung1/Api2.git "] & hit entered.
#
# - Now "Url" has been added, now my system knows where I have to send the code, whatever code, I have committed.
#
# - Till commit, everthing going to happen in local. Then we are trying to add the Gobal environment or Git we can say.
#
# -  Now my systems knows that, I have to send this particular code to this this location, a Git repository location.
#
# # 6.[" git push -u origin main " ]
#
# - Now finally the Push Origin, we have already added the main origin above code with URL.
#
# - Now over there "Git Push", Push the entire code and copy and paste this code -> [ " git push -u origin main "] & hit enter.
#
# - As we can see that, status below terminal that, it has pushed the entire code & if we go back to "GitHub" and refresh or load
# - the page then it has been updated successfully. and we will be able to see all folders and with codes.

# %% [markdown]
# # Deploy -> [ "Render" ]

# %% [markdown]
# - Go to Google this is an Url - [" https://render.com/ "]
#
# - 1st login with email id & Left top corner - Click on "Project" and after that right top corner ->
#
# - Now I can try to craete an Application, right corner click on the ["Add New"] & select the ["Web service"] option.
# - Next we redirect to another page, here if we are doing very 1st time then, will asked 3 options to provide.
#
#  # Git Provider | Public Git Repository | Existing Image
#
# - So, lets select 1st one -> (" Git Provider "), just select the -> ("GitHub") & login.
#
# - Once logedin, it showing me all the repository which is already there inside my Github, so select our repositor name is -> ["Api2"]
# - Once select the my repository -> ["Api2"],  left side we can see that, Souces Code what does this mean?
# - "Source code" -> means it will be able to pull all Sources code into this "Render"
#
# # Which Language we have used?
#
# - Language - "Python 3"  keep as it is because we are using the Python language so.
#
#  # Branch Name ?
#
# - So, we are in the -> "main branch" we can check inside GitHub also.
#
#  # Build Command ?
#
# - This basically means, So whenever we trying to spin the machine, whenever it is trying to allocated the Machine, whenever it is
# - trying to allocate the resources, what kind of setup it is trying to suppose to do.
#
# # what kind of installation, it is suppose to do?
#
# - If we remember, we have attached the "requirement.txt" file and so bedefault it is showing over here in the -> Build command section.
#
# - what we have mention over it -> "requirement.txt" , Installation, for my this particular project -> I required 2 libaries.
# - (a) fastapi
# - (b) uvicorn
#
# - So, I have mention that, I need these 2 libaries, so bydefault what it will do when it will try to spin the machine, for our project,
# - It will try to do the Installation.
# - lets say, May be I have mention 10, 20 or 100 of libaries, So that machine, a instance a resources which is going to allocate inside
# - a machine.So, in that one it will try to install each and everything that we have mentioned over here inside my "requirements.txt".
#
# - This is the meaning of it.
#
# # Start Command ?
#
# - It means that, lets Suppose it is able to prepared the Machine our code is avaiable. Now when we have to start mean when we have to
# - launched the Application, so what is the command that we have given,  how we have launched the application.
# - It was Uvicorn and then file name and then app something like this we have given.
# - This was my Unvicorn code -> [" python -m uvicorn Api2:app --reload "]
#
# - We can give something like this inside this "Start Command"  ->  [" python -m uvicorn Api2:app --host 0.0.0.0 --port 10000 "]
#
# # Note :
# - Here "0.0.0.0" <- it means we are allowing the traffic from everywhere this is the actual meaning of it. But the port number
# - we can change may be from "10000" t0 10001 or 10008 or 30000 or 80000 etc any.
#
# - can we give multiple command?
# - Answer is no, For one server obviously there will be only one entry point,
# - so this is the entry point ->
# -  [" python -m uvicorn Api2:app --host 0.0.0.0 --port 10000 "] or [" uvicorn Api2:app --host 0.0.0.0 --port 10000 "]
#
#  # Instance Type :
# - For Hobby project :
#
# # Note :
#
# - Selecet this one "Free" one
#
# # Click and "Deploy web server"
#
# # Note :
#
# - If everything works fine, then we will be see deployemnt in sometime, its loading, but it showing error message then,
# - If everything is fine,then it will clone, from inside the "Github" &
#
# - It is trying to pull the code 1st of all, it is trying to connecting with Github and trying to pull the leads. one by one and
# - it started & we have to wait and it will within few minutes it will upload it, but in some of the project it will take the time.
# - As we can it status it showing ("Live"), It means this app is live whatever was working inside my local machine, Now it is
# - Global now.
# - In my local system, the Url was the something like this -> (" local host:8000 "), this was the URL basically.
#
# # Note :
#
# - If we notice then, URL also given here, if we scrolled up there is my Github profile (main).
#
# - there is "Service ID " & URL ->, which is live now and if we see complete URL -> "Https" added .
#
# - This is URL which, I have got it, after successfully uploaded -> [ " https://api2-1-q1bv.onrender.com "]
#
# - Lets go ahead and test it, everything is live, everything is up and running,  and If I am going to hit that URL, then it will redirect
# - Now once new tab open and just provide inside that URL ("/Docs") if we have to use the [ "Swigger UI" ]
#
# - This URL is Live & I have added in URL -> Docs now this is complete my URL -> [ https://api2-1-q1bv.onrender.com/docs ]
#
#
# - Just provide the "Docs". the way we do in our local host port NO. simply we have a URL which is the "Global" one.
# - As we can see, I am able to get my "PUT" & "DELETE" on this URL.

# %% [markdown]
# - Now As we can see, my URL is Global and anyone can access it. through this URL and test it.
#
# - This is called Backend deployment, there is no "UI" basically we have deployed our API's. Now anyone can consumed this API's.
# - I can test this API, anywhere I want, For example like :
# - 1.From the PostMan
# - 2.From the Swagger UI
# - 3.From the Curl or from Curl command etc.
#
# - This is our API -> [" https://api2-1-q1bv.onrender.com/" ] live API, we can see.
# -  Complete URL is -> [" https://api2-1-q1bv.onrender.com/docs "]
#
# - So, now we are in Swagger UI & we can test it, we can do the ["PUT & Delete"] & if I have to do Git and push operation,
# - we can do it - here.
# - Now we understand what is "route" & how we can pass the data.
#
# - This experiment that, whatever running in my "local machine" its live now, that it. "Https" means secure and live now.

# %% [markdown]
# # Successfully Deployed in :  ["Render"]
#
# - Now succsessfully we are able to deployed our Application on Render.
